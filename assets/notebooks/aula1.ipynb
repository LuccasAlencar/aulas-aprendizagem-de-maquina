# %%
# importar bibliotecas

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt

print("ok")
# Out:
# ok

# %%
# carregar o modelo
model = MobileNetV2(weights='imagenet')

print("modelo carregado")
# Out:
# ...
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# modelo carregado

# %%
# !wget -O img.jpg https://upload.wikimedia.org/wikipedia/commons/2/27/Coca_Cola_Flasche_-_Original_Taste.jpg

# outros links para testes
# https://upload.wikimedia.org/wikipedia/commons/2/27/Coca_Cola_Flasche_-_Original_Taste.jpg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4M8a-zZCwPfGE7J9FZGHOaVQT6vqkZv5vvA&s
# https://salandingpagespaasprod.blob.core.windows.net/institutional-public/storage/assets/card/main/img-9017-20250721-141606-802-119A-20250721-141513-374-3894_axor-2545-lta-3-4-mot-cor-9304.jpg.webp

print("imagem carregada")
# Out:
# --2026-02-23 18:14:01--  https://upload.wikimedia.org/wikipedia/commons/2/27/Coca_Cola_Flasche_-_Original_Taste.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:860:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5515416 (5.3M) [image/jpeg]
# Saving to: ‘img.jpg’
#
# img.jpg             100%[===================>]   5.26M  17.9MB/s    in 0.3s
#
# 2026-02-23 18:14:01 (17.9 MB/s) - ‘img.jpg’ saved [5515416/5515416]
#
# imagem carregada

# %%
# carregar imagem
img_path = 'img.jpg'
img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

plt.imshow(img)
plt.title("Imagem para classificação")
plt.axis('off')
plt.show()

print("imagem carregada")
# Out:
# imagem carregada

# %%
predictions = model.predict(x)
print("previsão gerados")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# previsão gerados

# %%
decoded_predictions = decode_predictions(predictions, top=3)[0]

print("o modelo acredita que a imagem é:")
for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
  print(f"{i+1}. {label} ({score*100:.2f}%)")
# Out:
# o modelo acredita que a imagem é:
# 1. pop_bottle (98.83%)
# 2. beer_bottle (0.51%)
# 3. beer_glass (0.07%)
